# %%
#changes the output of a game to a one hot encoding [win, tie, loss]
def resOneHot(y):
    if y == 3:
        return [1 , 0, 0]
    elif y == 1:
        return [0, 1, 0]
    else:
        return [0, 0, 1]

#creates a flat version of the x as a 1 x 8240 matrix and the y's as one hot vectors.
def createDataSet2(gameInfo, season):
    
    ''' code used to create x and y values from a given season and set of games
    creates a y value that is listed as a one hot vector
     and x as a 1 x 8240 matrix that give information about the past 5 games'''
    x = []
    y = []
    cnt = 0
    teamDic = dict()
    teams = season.teams
    #this code block is meant to fix a mistake in the definition of my data structure, should really make performances
    # a dictionary which each team name as a key, and the performances as a val. 
    for team in teams:
        teamDic[team] = cnt
        cnt += 1
    for game in gameInfo:
        example = []
        stage = game[0]
        res = game[5]
        #the result of the game will constitute our y set. 0 = home loss, 1 = home draw, 3 = home win.
        y.append(resOneHot(res))
        home = game[1]
        away = game[2]
        homeLoc = teamDic[home]
        awayLoc = teamDic[away]
        #a training example will be a 10 * 824, with the home teams most recent 5 games as the first 5 values
        #followed by the away teams most recent 5 games.
        for i in range((stage-6), (stage - 1)):
            game = season.performances[homeLoc].performance[i]
            #first two items in game are the stage and away team api Id which I don't use in this
            # model
            game1 = game[2:]
            if len(game1) < 824:
                for k in range(len(game1), 824):
                    game1.append(0)
            if len(game1) != 824:        
                print(len(game1))
            for d in game1:
                example.append(d)
        for j in range((stage-6), (stage - 1)):
            game = season.performances[awayLoc].performance[i]
            game1 = game[2:]
            if len(game1) < 824:
                for k in range(len(game1), 824):
                    game1.append(0)
            if len(game1) != 824:        
                print(len(game1))
            for d in game1:
                example.append(d)
        x.append(example)
    return x, y

# %%
#this is still in progress working on building neural network to predict games
import pickle
import math
POOL = 4
W1 = 32
W2 = 16
W3 = 8
WF1 = 256
NUMFEATURES = 3
D1 = 32 #depths
D2 = 64
D3 = 128


def cw(nLayers, p, w= 824):
    ''' calculates the width for fully connected layer
    args are number of layers,
    pool size, and the width of the argument default to 824'''
    w1 = float(w)
    for i in range(nLayers):
        w1 = math.ceil(w1/p)
    return w1
W_FINAL = cw(3, POOL)

with open('soccerPerformance3.pickle', 'rb') as handle:
    b3 = pickle.load(handle)
with open('soccerInfo.pickle', 'rb') as handle:
    b = pickle.load(handle)

season1 = b.seasonData[0].pVals[0]
season2 = b.seasonData[1].pVals[0]
t1 = season1.info[50:]
t2 = season2.info[50:]
xT1, yT1 = createDataSet2(t1, season1)
xT2, yT2 = createDataSet2(t2, season2)
xTrain2 = xT1 + xT2  
yTrain2 = yT1 + yT2
testGames = b3.info[50:]


xTest2, yTest2 = createDataSet2(testGames, b3)

import random as rand
def genBatch(x, y, n =100):
    x1 = []
    y1 = []
    a = []
    for j in range(len(y)):
        a.append(j)
        rand.shuffle(a)
    for i in range(n):
        j = a[i]
        x1.append(x[j])
        y1.append(y[j])
    return x1, y1
    
import tensorflow as tf
sess = tf.InteractiveSession()
def weight_variable(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 4, 2, 1],
                        strides=[1, 4, 2, 1], padding='SAME')

x = tf.placeholder(tf.float32, shape=[None, 8240])
y_ = tf.placeholder(tf.float32, shape=[None, 3])

W_conv1 = weight_variable([W1, 10, 1, D1])
b_conv1 = bias_variable([D1])
x_image = tf.reshape(x, [-1,824,10,1])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([W2, 4, D1, D2])
b_conv2 = bias_variable([D2])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_conv3 = weight_variable([W3, 2, D2, D3])
b_conv3 = bias_variable([D3])

h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3)
h_pool3 = max_pool_2x2(h_conv3)

W_fc1 = weight_variable([W_FINAL * 2 * D3, WF1])
b_fc1 = bias_variable([WF1])
h_pool3_flat = tf.reshape(h_pool3, [-1,W_FINAL * 2 * D3])
h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weight_variable([256, 3])
b_fc2 = bias_variable([3])

y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2


cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(y_conv, y_))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

sess.run(tf.initialize_all_variables())
for i in range(10000):
    x_batch, y_batch = genBatch(xTrain2, yTrain2) 
  
    if i%100 == 0:
        train_accuracy = accuracy.eval(feed_dict={
            x:x_batch, y_: y_batch, keep_prob: 1.0})
        print("step %d, training accuracy %g"%(i, train_accuracy))
        train_step.run(feed_dict={x: x_batch, y_:y_batch, keep_prob: 0.5})

print("test accuracy %g"%accuracy.eval(feed_dict={
    x: xTest2, y_: yTest2, keep_prob: 1.0}))
# Out:
# WARNING:tensorflow:From <ipython-input-6-28395ea5bb59>:114 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# step 0, training accuracy 0.2
# step 100, training accuracy 0.29
# step 200, training accuracy 0.45
# step 300, training accuracy 0.59
# step 400, training accuracy 0.52
# step 500, training accuracy 0.38
# step 600, training accuracy 0.24
# step 700, training accuracy 0.26
# step 800, training accuracy 0.34
# step 900, training accuracy 0.39
# step 1000, training accuracy 0.46
# step 1100, training accuracy 0.46
# step 1200, training accuracy 0.51
# step 1300, training accuracy 0.41
# step 1400, training accuracy 0.47
# step 1500, training accuracy 0.52
# step 1600, training accuracy 0.37
# step 1700, training accuracy 0.4
# step 1800, training accuracy 0.42
# step 1900, training accuracy 0.47
# step 2000, training accuracy 0.49
# step 2100, training accuracy 0.49
# step 2200, training accuracy 0.49
# step 2300, training accuracy 0.46
# step 2400, training accuracy 0.51
# step 2500, training accuracy 0.38
# step 2600, training accuracy 0.44
# step 2700, training accuracy 0.41
# step 2800, training accuracy 0.43
# step 2900, training accuracy 0.51
# step 3000, training accuracy 0.47
# step 3100, training accuracy 0.52
# step 3200, training accuracy 0.49
# step 3300, training accuracy 0.42
# step 3400, training accuracy 0.54
# step 3500, training accuracy 0.53
# step 3600, training accuracy 0.54
# step 3700, training accuracy 0.51
# step 3800, training accuracy 0.52
# step 3900, training accuracy 0.48
# step 4000, training accuracy 0.41
# step 4100, training accuracy 0.48
# step 4200, training accuracy 0.55
# step 4300, training accuracy 0.52
# step 4400, training accuracy 0.48
# step 4500, training accuracy 0.43
# step 4600, training accuracy 0.37
# step 4700, training accuracy 0.49
# step 4800, training accuracy 0.52
# step 4900, training accuracy 0.49
# step 5000, training accuracy 0.57
# step 5100, training accuracy 0.54
# step 5200, training accuracy 0.51
# step 5300, training accuracy 0.47
# step 5400, training accuracy 0.51
# step 5500, training accuracy 0.45
# step 5600, training accuracy 0.51
# step 5700, training accuracy 0.56
# step 5800, training accuracy 0.43
# step 5900, training accuracy 0.46
# step 6000, training accuracy 0.55
# step 6100, training accuracy 0.47
# step 6200, training accuracy 0.55
# step 6300, training accuracy 0.5
# step 6400, training accuracy 0.58
# step 6500, training accuracy 0.54
# step 6600, training accuracy 0.51
# step 6700, training accuracy 0.55
# step 6800, training accuracy 0.55
# step 6900, training accuracy 0.5
# step 7000, training accuracy 0.49
# step 7100, training accuracy 0.49
# step 7200, training accuracy 0.55
# step 7300, training accuracy 0.49
# step 7400, training accuracy 0.59
# step 7500, training accuracy 0.52
# step 7600, training accuracy 0.49
# step 7700, training accuracy 0.53
# step 7800, training accuracy 0.56
# step 7900, training accuracy 0.59
# step 8000, training accuracy 0.53
# step 8100, training accuracy 0.45
# step 8200, training accuracy 0.5
# step 8300, training accuracy 0.61
# step 8400, training accuracy 0.53
# step 8500, training accuracy 0.49
# step 8600, training accuracy 0.5
# step 8700, training accuracy 0.54
# step 8800, training accuracy 0.46
# step 8900, training accuracy 0.47
# step 9000, training accuracy 0.54
# step 9100, training accuracy 0.47
# step 9200, training accuracy 0.57
# step 9300, training accuracy 0.58
# step 9400, training accuracy 0.56
# step 9500, training accuracy 0.6
# step 9600, training accuracy 0.56
# step 9700, training accuracy 0.49
# step 9800, training accuracy 0.51
# step 9900, training accuracy 0.65
# test accuracy 0.40303
