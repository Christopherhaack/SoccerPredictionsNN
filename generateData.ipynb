# %%
from data_import import *
b2 = soccerInfo()
import pickle



with open('soccerPerformancePrem.pickle', 'wb') as handle:
    pickle.dump(b2, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('soccerPerformancePrem.pickle', 'rb') as handle:
    b3 = pickle.load(handle)
print(b3.performances[0].performance[0])
# Out:
# 2008/2009
# 2009/2010
# 2010/2011
# 2011/2012
# 2012/2013
# 2013/2014
# 2014/2015
# 2015/2016
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-fe28bb0d31a6> in <module>()
#      10 with open('soccerPerformancePrem.pickle', 'rb') as handle:
#      11     b3 = pickle.load(handle)
# ---> 12 print(b3.performances[0].performance[0])
#
# AttributeError: 'soccerInfo' object has no attribute 'performances'

# %%
with open('soccerPerformancePrem.pickle', 'rb') as handle:
    b3 = pickle.load(handle)
print(b3.seasonData[2].pVals[0].performances[0].performance[0])
# Out:
# [1, 8659, 3, 6, 0, 2, 4, 6, 8, 3, 5, 7, 3, 5, 7, 1, 2, 4, 6, 8, 2, 4, 6, 8, 5, 5, 1, 3, 3, 3, 3, 7, 7, 7, 10, 10, 10, 1, 3, 3, 3, 3, 7, 7, 7, 7, 9, 11, 89, 92, 9, 8, 19, 25, 17, 9, 9, 87, 82, 24, 58, 59, 49, 83, 60, 21, 79, 48, 74, 11, 57, 77, 50, 45, 87, 8, 8, 12, 90, 86, 82, 91, 94, 83, 86, 84, 27, 84, 85, 47, 44, 67, 83, 62, 78, 81, 78, 69, 77, 75, 32, 73, 83, 79, 29, 68, 78, 80, 70, 83, 83, 84, 81, 8, 5, 62, 11, 5, 87, 88, 38, 47, 92, 58, 63, 56, 48, 76, 52, 82, 91, 84, 55, 87, 78, 79, 89, 89, 86, 51, 61, 70, 80, 66, 76, 86, 83, 81, 12, 11, 52, 9, 12, 91, 90, 13, 16, 93, 52, 55, 48, 44, 83, 43, 67, 73, 85, 49, 82, 83, 38, 91, 87, 93, 15, 93, 86, 91, 63, 83, 93, 95, 87, 7, 8, 43, 8, 12, 83, 89, 81, 32, 73, 76, 63, 73, 68, 88, 59, 78, 85, 91, 83, 87, 73, 23, 77, 94, 81, 23, 54, 80, 83, 73, 88, 82, 90, 92, 7, 8, 59, 9, 7, 90, 92, 72, 84, 62, 92, 87, 82, 87, 86, 90, 90, 83, 83, 76, 92, 83, 87, 67, 92, 89, 94, 84, 83, 88, 89, 86, 69, 86, 64, 10, 6, 90, 9, 6, 73, 90, 60, 47, 72, 72, 61
# ...
